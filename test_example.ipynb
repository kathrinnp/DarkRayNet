# %%
import numpy as np
from sim_tool import antiproton_sim, primary_sim, interface_sim
sim = antiproton_sim(x = True)
sim_p = primary_sim()
# Out:
# The antiproton simulation tool has been initiated.
# The primary (p,He) simulation tool has been initiated.

# %%
import matplotlib.pyplot as plt
plt.rcParams['pgf.rcfonts'] = False
plt.rcParams['font.family'] = "DejaVu Sans"
plt.rcParams['font.serif'] = []
plt.rcParams['text.usetex'] = True
plt.rcParams['axes.formatter.useoffset'] = False
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['errorbar.capsize'] = 2
plt.rcParams['grid.linewidth'] = 2
plt.rcParams['axes.labelsize'] = 14

c_RWTH = {'b': '#00549F',  # blue
          'lb': '#8EBAE5', # light blue
          'dr': '#A11035', # dark red
          'g': '#57AB27',  # green
          't': '#006165',  # teal / petrol
          'o': '#F6A800',  # orange
          'lg': '#BDCD00', # light green
          'gr': '#646567', # gray
          'v': '#612158',  # violett
          'r': '#CC071E',  # red
          'tq': '#0098A1', # turquoise
          'p': '#7A6FAC'}  # purple

# %%
test_mDM = 5 #log10(mDM/MeV)
test_mDM_N =np.array([4, 5, 6])

test_fs = np.ones(8)* 1/8 #equal branching fractions
test_fs_N = np.repeat([test_fs], 3, axis = 0) 

test_pp = np.array([1.70694e+00, 1.67743e+00, 2.44673e+00, 2.41569e+00, 7.56688e+03, 4.22478e-01, 2.79565e+28, 3.78306e-01, 1.75379e+01, 4.82479e-01, 3.05006e+00]) # arbitrary propagation model
test_pp_N = np.repeat([test_pp], 3, axis = 0)

# %%
tot, DM, s, E = sim.single_sim(test_pp, test_mDM, test_fs)

plt.figure(figsize=(8,6))
plt.title('Cosmic Ray Antiproton Flux')
plt.plot(E, E**2.7 * tot, c = c_RWTH['b'], linestyle = 'dashed', label = 'total antiproton flux')
plt.plot(E, E**2.7 * s, c = c_RWTH['g'], linestyle = 'dotted', label = 'secondary antiproton flux')
plt.plot(E, E**2.7 * DM, c = c_RWTH['dr'], linestyle = 'dashdot', label = 'DM antiproton flux')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.ylabel('$\Phi \cdot E^{2.7}$ [GeV$^{1.7}$ m$^{-2}$ sr$^{-1}$ s$^{-1}$]')
plt.xlabel('E [GeV]')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d6e626540045> in <module>
# ----> 1 tot, DM, s, E = sim.single_sim(test_pp, test_mDM, test_fs)
#       2
#       3 plt.figure(figsize=(8,6))
#       4 plt.title('Cosmic Ray Antiproton Flux')
#       5 plt.plot(E, E**2.7 * tot, c = c_RWTH['b'], linestyle = 'dashed', label = 'total antiproton flux')
#
# ~/Documents/Work/Projects/DarkRayNet/sim_tool.py in single_sim(self, propagation_parameters, DM_mass, DM_fs)
#      26         propagation_parameters_s = ((propagation_parameters - np.array(self.S_trafos[0])[:11])/np.array(self.S_trafos[1])[:11])
#      27         s_flux = 10**self.S_model.predict(np.repeat([propagation_parameters_s], 2, axis = 0))[0]/self.E_bins**2.7
# ...

# %%
tot, DM, s, E = sim.x_sim(test_pp_N, test_mDM_N, test_fs_N)

plt.figure(figsize=(8,6))
plt.title('DM Component')
plt.plot(E, E**2.7 * DM[0], c = c_RWTH['b'], linestyle = 'dashed', label = r'$m_\mathrm{DM} = 10$ GeV')
plt.plot(E, E**2.7 * DM[1], c = c_RWTH['g'], linestyle = 'dotted', label = r'$m_\mathrm{DM} = 100$ GeV')
plt.plot(E, E**2.7 * DM[2], c = c_RWTH['dr'], linestyle = 'dashdot', label = r'$m_\mathrm{DM} = 1$ TeV')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.ylabel('$\Phi \cdot E^{2.7}$ [GeV$^{1.7}$ m$^{-2}$ sr$^{-1}$ s$^{-1}$]')
plt.xlabel('E [GeV]')
plt.show()

# %%
p, D, He4, He3, E = sim_p.single_sim(test_pp)

plt.figure(figsize=(8,6))
plt.title('Cosmic Ray Proton Flux')
plt.plot(E, E**2.7 * p, c = c_RWTH['b'], linestyle = 'dashed', label = r'Protons')
plt.plot(E, E**2.7 * D, c = c_RWTH['g'], linestyle = 'dotted', label = r'Deuterium')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.ylabel('$\Phi \cdot E^{2.7}$ [GeV$^{1.7}$ m$^{-2}$ sr$^{-1}$ s$^{-1}$]')
plt.xlabel('E [GeV]')
plt.show()
# Out:
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbbcbeed550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
plt.figure(figsize=(8,6))
plt.title('Cosmic Ray Helium Flux')
plt.plot(E, E**2.7 * He4, c = c_RWTH['b'], linestyle = 'dashed', label = r'Helium 4')
plt.plot(E, E**2.7 * He3, c = c_RWTH['g'], linestyle = 'dotted', label = r'Helium 3')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.ylabel('$\Phi \cdot E^{2.7}$ [GeV$^{1.7}$ m$^{-2}$ sr$^{-1}$ s$^{-1}$]')
plt.xlabel('E [GeV]')
plt.show()

# %%
i_sim = interface_sim()
# Out:
# The simulation tool has been initiated.

# %%
test_DM_flux, E = i_sim.DM_sim(test_pp, 5, np.ones(8)*0.125)

print(test_DM_flux)
# Out:
# [4.93759051e-03 5.24759315e-03 5.38503239e-03 5.29159309e-03
#  4.98651472e-03 4.49802242e-03 3.87458782e-03 3.18186221e-03
#  2.47965288e-03 1.83545187e-03 1.29395560e-03 8.71056920e-04
#  5.62463904e-04 3.48407322e-04 2.03829760e-04 1.11152632e-04
#  5.63959160e-05 2.67022428e-05 1.14997307e-05 4.03018037e-06
#  1.01307498e-06 1.94481971e-07 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]

# %%
plt.figure(figsize=(8,6))
plt.title('DM Component')
plt.plot(E, E**2.7 * test_DM_flux, c = c_RWTH['b'], linestyle = 'dashed')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('$\Phi \cdot E^{2.7}$ [GeV$^{1.7}$ m$^{-2}$ sr$^{-1}$ s$^{-1}$]')
plt.xlabel('E [GeV]')
plt.show()
